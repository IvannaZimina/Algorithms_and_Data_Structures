# %% [markdown]
# 1. Course Structure
#   - Data Structures
#   - Arrays and Linked Lists
#   - Stacks and Queues
#   - Trees (Binary Trees, Balanced Trees, AVL Trees)
#   - Heaps
#   - Graphs
#   - Hash Tables
#
# 2. Algorithms
#   - Sorting Algorithms
#   - Searching Algorithms
#   - String Matching
#   - Graph Algorithms (Dijkstra, Prim, Kruskal)
#   - Algorithm Analysis
#   - Problem-solving techniques
