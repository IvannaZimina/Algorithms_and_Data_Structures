# %% [markdown]
# #### 1. Data structures:
#
# 1) Fundamental questions about algorithms, purposes of algorithm analysis, levels of abstract in data structures, classification of data structures.
#
# 2) Array, linked list, circular linked list, doubly linked list.
# 	In a linked list with the nodes A → B → C → D, if the next attribute of node B is set to None, what will be the resulting linked list?
# 	How can you determine if a linked list is circular?
# 	How do you find out when the traversal completes in a circular linked list?
# 	How do you check if a circular linked list is empty?
# 	Can a circular linked list contain duplicate values?
# 	How do you convert a circular linked list into a singly linked list?
# 	How is a node represented in a doubly linked list?
# 	How do you find the length of a doubly linked list?
#
# 3) Stack, queue, circular queue, dequeue
# 4) Graphs, types of representation, relation between graphs, graph types
# 5) Trees and their properties, forest, binary trees
# 6) Balanced trees, imbalances and rotations, AVL-tree, RB-tree
# 7) Heaps and hashing
#
# #### 2. Algorithms
#
# 1)  Sorting: Bubble sort, Selection sort, Insertion sort, Merge sort
# 2)  Sorting: Quick sort, Counting sort, Bucket sort, Radix sort, Shell sort
# 3)  Searching algorithms: Linear search, Binary search.
# 4)  String matching: Brute Force, Rabin-Karp, KMP
# 5)  Graph algorithms: Dijkstra, Prim, Kruskal, Floyd
# 6)  Algorithm analysis: asymptotic notation, master theorem, space complexity
