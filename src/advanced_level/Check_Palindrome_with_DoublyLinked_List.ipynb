# %% [markdown]
# Check Palindrome with Doubly Linked List
# Add method to check if a doubly linked list is a palindrome.
#
# Conditons:
#
#
# - DoublyLinkedList class made in Basic tasks must be used
# - `is_palindrome(self)->bool` must be `DoublyLinkedList's` method
# Examples:
#
#
# ```python
# > 11 22 33 44
# False
#
#
# > 4 2 2 4
# True
# ```
