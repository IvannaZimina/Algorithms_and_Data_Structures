# %% [markdown]
# Remove Duplicates From a Sorted Linked List
# Suppose we are given a sorted linked list. And we have to remove the consecutive duplicates from it.
#
# Conditons:
#
#
# LinkedList class made on Practical Session 1 must be used
# `remove_duplicates()` must be LinkedList's method
# Example:
#
#
# ```python
# > ll.display()
# > ll.remove_duplicates()
# > ll.display
# 30->55->55->80->80->80
# 30->55->80
# ```
