# %% [markdown]
# Reverse a Circular Linked List
# Add method to reverse a circular linked list.
#
# Conditons:
#
#
# CircularLinkedList class made on Practical Session 1 must be used
# `reverse()` must be CircularLinkedList's method
# Example:
#
#
# ```python
# > 11 22 33 44
# 44->33->22->11->44
# ```
